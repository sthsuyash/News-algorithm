# %%
from gensim.models import KeyedVectors

# Load the text format embedding
# word_vector = KeyedVectors.load_word2vec_format(
#     'models/nepali_embeddings_word2vec.txt', binary=False)

# # Save it in binary format for future use
# word_vector.save("models/nepali_embeddings_word2vec.kv")

# %%
global word_vector
word_vector = KeyedVectors.load("models/nepali_embeddings_word2vec.kv")

# %%
word_vector.similarity('फेसबूक', 'ट्विटर')
# Out:
# 0.6708383

# %%
word_vector.key_to_index
# Out:
# {'पनि': 0,
#  'भए': 1,
#  'गरे': 2,
#  '‘': 3,
#  '’': 4,
#  'छन्': 5,
#  'गर्न': 6,
#  'लागि': 7,
#  'उन': 8,
#  'नेपाल': 9,
#  'गर्ने': 10,
#  'थियो': 11,
#  'तथा': 12,
#  'रहे': 13,
#  'सरकार': 14,
#  'यस': 15,
#  'गरि': 16,
#  'हुने': 17,
#  'बताए': 18,
#  'तर': 19,
#  'थिए': 20,
#  'काम': 21,
#  'वर्ष': 22,
#  'एक': 23,
#  'छैन': 24,
#  'कु': 25,
#  'आए': 26,
#  'क्षेत्र': 27,
#  'भन्ने': 28,
#  'त्यस': 29,
#  'निर्माण': 30,
#  'जना': 31,
#  'गरी': 32,
#  'अनुसार': 33,
#  'नेपाली': 34,
#  'दिन': 35,
#  'प्रतिक्रिया': 36,
#  'स्थानीय': 37,
#  'सबै': 38,
#  'हजार': 39,
#  'हुन्छ': 40,
#  'केही': 41,
#  'प्रदेश': 42,
#  'गर्': 43,
#  'प्रहरी': 44,
#  'नयाँ': 45,
#  'हामी': 46,
#  'सय': 47,
#  'विकास': 48,
#  'जिल्ला': 49,
#  'कारण': 50,
#  'समय': 51,
#  'उनी': 52,
#  'कुरा': 53,
#  'देखि': 54,
#  'दुई': 55,
#  'नाम': 56,
#  'मात्र': 57,
#  'रुप': 58,
#  'आफ्नो': 59,
#  'रूप': 60,
#  'लाख': 61,
#  'धेरै': 62,
#  'कार्यालय': 63,
#  'अहि': 64,
#  'अवस्था': 65,
#  'समिति': 66,
# ...
